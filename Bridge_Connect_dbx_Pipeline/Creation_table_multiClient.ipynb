# %% [markdown]
# # Preparation SQL table DeltaSharing AGT BridgeConnect

# %% [markdown]
# ## À rouler une seule fois

# %%
# %sql
ALTER TABLE bridge_dev.bridge_connect.referrals
SET TBLPROPERTIES (delta.enableChangeDataFeed = true);

# %%
# %sql
CREATE TABLE IF NOT EXISTS deltasharing_dev.agt.references_bridge_connect
AS
SELECT *
FROM bridge_dev.bridge_connect.referrals
WHERE 1 = 0;


INSERT INTO deltasharing_dev.agt.references_bridge_connect
SELECT *
FROM bridge_dev.bridge_connect.referrals
WHERE source_db = 'db0' or source_db = 'db2'; 

-- db0 => agtConcours
-- db2 => agtGeneral
